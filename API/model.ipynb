# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.metrics import r2_score
import category_encoders as ce
from sklearn.model_selection import train_test_split

# import dataset
df = pd.read_csv('dataset_gold.csv')

df.info()

df['genres']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10726 entries, 0 to 10725
# Data columns (total 66 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   titre                  10726 non-null  object
#  1   date                   4157 non-null   object
#  2   durée                  10726 non-null  float64
#  3   réalisateur            10726 non-null  object
#  4   distributeur           10726 non-null  object
#  5   acteurs                10726 non-null  object
#  6   nationalités           10726 non-null  object
#  7   langue_d_origine       10726 non-null  object
#  8   type_film              10726 non-null  object
#  9   annee_production       10726 non-null  int64
#  10  box_office_total       8819 non-null   float64
#  11  note_presse            10726 non-null  float64
#  12  note_spectateurs       10726 non-null  float64
#  13  nombre_article         10300 non-null  float64
#  14  description            9657 non-null   object
#  15  boxoffice              10726 non-null  int64
#  16  genres                 10726 non-null  object
#  17  awards                 10726 non-null  int64
#  18  nominations            10726 non-null  int64
#  19  nombre_acteurs_connus  10726 non-null  int64
#  20  acteurs_connus         10726 non-null  object
#  21  realisateur_connu      10726 non-null  int64
#  22  t                      10726 non-null  int64
#  23  a                      10726 non-null  int64
#  24  c                      10726 non-null  int64
#  25  m                      10726 non-null  int64
#  26  H                      10726 non-null  int64
#  27  A                      10726 non-null  int64
#  28  é                      10726 non-null  int64
#  29  P                      10726 non-null  int64
#  30  y                      10726 non-null  int64
#  31  _                      10726 non-null  int64
#  32  r                      10726 non-null  int64
#  33  p                      10726 non-null  int64
#  34  o                      10726 non-null  int64
#  35  ]                      10726 non-null  int64
#  36  s                      10726 non-null  int64
#  37  l                      10726 non-null  int64
#  38  D                      10726 non-null  int64
#  39  M                      10726 non-null  int64
#  40  F                      10726 non-null  int64
#  41  q                      10726 non-null  int64
#  42  -                      10726 non-null  int64
#  43  h                      10726 non-null  int64
#  44  T                      10726 non-null  int64
#  45                         10726 non-null  int64
#  46  u                      10726 non-null  int64
#  47  f                      10726 non-null  int64
#  48  w                      10726 non-null  int64
#  49  d                      10726 non-null  int64
#  50  G                      10726 non-null  int64
#  51  J                      10726 non-null  int64
#  52  [                      10726 non-null  int64
#  53  i                      10726 non-null  int64
#  54  B                      10726 non-null  int64
#  55  n                      10726 non-null  int64
#  56  v                      10726 non-null  int64
#  57  E                      10726 non-null  int64
#  58  W                      10726 non-null  int64
#  59  S                      10726 non-null  int64
#  60  x                      10726 non-null  int64
#  61  R                      10726 non-null  int64
#  62  '                      10726 non-null  int64
#  63  C                      10726 non-null  int64
#  64  g                      10726 non-null  int64
#  65  e                      10726 non-null  int64
# dtypes: float64(5), int64(50), object(11)
# memory usage: 5.4+ MB
# 0         ['Animation_Comédie_Famille']
# 1                   ['Comédie_Famille']
# 2                           ['Comédie']
# 3            ['Action_Guerre_Thriller']
# 4                ['Comédie dramatique']
#                       ...
# 10721                         ['Drame']
# 10722                         ['Drame']
# 10723                       ['Comédie']
# 10724                       ['Comédie']
# 10725    ['Comédie dramatique_Romance']
# Name: genres, Length: 10726, dtype: object

# %%
X = df.drop(['boxoffice','date','acteurs','awards','box_office_total','réalisateur','genres',
        'description','nominations','note_presse','note_spectateurs', 'nombre_article','acteurs_connus','titre','y', ']', 'w', '[', "'"], axis=1)
y = df['boxoffice']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, shuffle=True, random_state=42)
# print(X)
# Define catboost encoder
cbe_encoder = ce.cat_boost.CatBoostEncoder()
  
# Fit encoder and transform the features
cbe_encoder.fit(X, y)
cbe_encoder.fit(X_train, y_train)
X_train_cbe = cbe_encoder.transform(X_train)
X_test_cbe = cbe_encoder.transform(X_test)

print(X_train.columns)

print(X.columns)

# ['durée', 'distributeur', 'nationalités', 'langue_d_origine',
#        'type_film', 'annee_production', 'nombre_acteurs_connus',
#        'realisateur_connu', 'r', 'W', 'd', 'v', 'n', '_', ' ', 'E', 'R', 'S',
#        'p', 'g', 'x', 'o', 'é', 'D', 'c', ',', 'B', 'f', 'l', 'C', 't', '-',
#        'u', 'q', 'G', 'F', 'J', 'e', 'A', 'M', 's', 'h', 'T', 'H', 'm', 'P',
#        'i', 'a'],

# ['titre', 'durée', 'distributeur', 'réalisateur', 'nationalités',
#        'langue_d_origine', 'type_film', 'genres', 'annee_production',
#        'acteurs', 'acteurs_connus', 'nombre_acteurs_connus',
#        'realisateur_connu', 'Biopic_Drame', 'Drame_Science fiction',
#        'Animation_Drame_Fantastique', 'Action_Animation_Aventure_Fantastique',
#        'Action_Aventure', 'Comédie musicale_Romance',
#        'Aventure_Comédie_Famille',
#        'Action_Animation_Arts Martiaux_Fantastique', 'Policier_Romance',
#        'Aventure_Comédie_Famille_Fantastique', 'Western', 'Aventure_Famille',
#        'Action_Animation_Aventure_Fantastique_Science fiction',
#        'Action_Comédie_Thriller', 'Action_Espionnage_Thriller',
#        'Drame_Historique', 'Action_Comédie_Espionnage', 'Drame_Policier',
#        'Action_Thriller', 'Drame_Romance', 'Comédie_Drame_Romance',
#        'Drame_Guerre', 'Animation_Comédie_Drame',
#        'Epouvante-horreur_Fantastique', 'Action_Aventure_Fantastique',
#        'Policier', 'Thriller', 'Biopic_Epouvante-horreur_Fantastique',
#        'Action_Drame', 'Drame_Judiciaire_Thriller', 'Comédie dramatique',
#        'Policier_Thriller', 'Comédie dramatique_Romance', 'Comédie_Romance',
#        'Drame_Erotique', 'Drame', 'Comédie_Drame',
#        'Action_Aventure_Science fiction', 'Action_Aventure_Policier_Thriller',
#        'Science fiction_Thriller', 'Action_Policier',
#        'Aventure_Science fiction', 'Aventure_Comédie',
#        'Animation_Comédie_Famille', 'Epouvante-horreur_Thriller',
#        'Animation_Famille', 'Action_Animation_Aventure_Comédie musicale',
#        'Aventure_Fantastique', 'Epouvante-horreur_Science fiction_Thriller',
#        'Comédie', 'Comédie dramatique_Comédie_Drame',
#        'Animation_Famille_Fantastique', 'Epouvante-horreur', 'Drame_Thriller',
#        'Drame_Romance_Thriller'],
# Out:
# Index(['durée', 'distributeur', 'nationalités', 'langue_d_origine',
#        'type_film', 'annee_production', 'nombre_acteurs_connus',
#        'realisateur_connu', 't', 'a', 'c', 'm', 'H', 'A', 'é', 'P', '_', 'r',
#        'p', 'o', 's', 'l', 'D', 'M', 'F', 'q', '-', 'h', 'T', ' ', 'u', 'f',
#        'd', 'G', 'J', 'i', 'B', 'n', 'v', 'E', 'W', 'S', 'x', 'R', 'C', 'g',
#        'e'],
#       dtype='object')
# Index(['durée', 'distributeur', 'nationalités', 'langue_d_origine',
#        'type_film', 'annee_production', 'nombre_acteurs_connus',
#        'realisateur_connu', 't', 'a', 'c', 'm', 'H', 'A', 'é', 'P', '_', 'r',
#        'p', 'o', 's', 'l', 'D', 'M', 'F', 'q', '-', 'h', 'T', ' ', 'u', 'f',
#        'd', 'G', 'J', 'i', 'B', 'n', 'v', 'E', 'W', 'S', 'x', 'R', 'C', 'g',
#        'e'],
#       dtype='object')

# %%
import pandas as pd
from catboost import CatBoostRegressor    # For regression tasks use CatBoostRegressor, for classification use CatBoostClassifier
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error  # For regression tasks


# Identifier les caractéristiques catégorielles
categorical_features = ['distributeur', 'nationalités', 'langue_d_origine','type_film']

# Sélectionner automatiquement les caractéristiques numériques en filtrant les colonnes du DataFrame X
numerical_features = X.select_dtypes(include=['int64', 'float64']).columns.tolist()

cbe_encoder = ce.cat_boost.CatBoostEncoder()

# Créer un pipeline pour les prétraitements
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', cbe_encoder, categorical_features)
    ])

# Créer le modèle CatBoost
model = CatBoostRegressor(iterations=100, depth=6, learning_rate=0.1, loss_function='RMSE')

# Créer le pipeline
pipeline = Pipeline([
        ('preprocessor', preprocessor), 
        ('model', model)
])

# Entraîner le modèle sur les données d'entraînement
pipeline.fit(X_train, y_train)

# Faire des prédictions sur les données de test
y_pred = pipeline.predict(X_test)

y_pred_train = pipeline.predict(X_train)
# Out:
# 0:	learn: 2915380.3083857	total: 2.81ms	remaining: 278ms
# 1:	learn: 2855558.9088903	total: 5.62ms	remaining: 275ms
# 2:	learn: 2805936.8536819	total: 8.71ms	remaining: 282ms
# 3:	learn: 2757244.8113804	total: 11.6ms	remaining: 278ms
# 4:	learn: 2724880.8953881	total: 14.3ms	remaining: 271ms
# 5:	learn: 2696987.9135992	total: 16.7ms	remaining: 262ms
# 6:	learn: 2666372.6491811	total: 19ms	remaining: 253ms
# 7:	learn: 2642697.8957097	total: 21.9ms	remaining: 252ms
# 8:	learn: 2620040.3018598	total: 24.6ms	remaining: 249ms
# 9:	learn: 2601648.9957887	total: 27.6ms	remaining: 248ms
# 10:	learn: 2586019.5302293	total: 30.2ms	remaining: 244ms
# 11:	learn: 2566169.9892497	total: 32.7ms	remaining: 240ms
# 12:	learn: 2555864.1973574	total: 35.4ms	remaining: 237ms
# 13:	learn: 2545938.4315884	total: 38.3ms	remaining: 235ms
# 14:	learn: 2536678.4524648	total: 41.3ms	remaining: 234ms
# 15:	learn: 2523025.8010708	total: 44.6ms	remaining: 234ms
# 16:	learn: 2516037.1823264	total: 47.1ms	remaining: 230ms
# 17:	learn: 2511605.7050619	total: 50.1ms	remaining: 228ms
# 18:	learn: 2501621.8236304	total: 52.9ms	remaining: 226ms
# 19:	learn: 2493826.6993934	total: 55.9ms	remaining: 224ms
# 20:	learn: 2481682.6248923	total: 58.5ms	remaining: 220ms
# 21:	learn: 2477732.0438167	total: 61.1ms	remaining: 217ms
# 22:	learn: 2467404.4971136	total: 63.6ms	remaining: 213ms
# 23:	learn: 2463672.3405744	total: 66.3ms	remaining: 210ms
# 70:	learn: 2332983.4520423	total: 197ms	remaining: 80.6ms
# 71:	learn: 2328479.5516068	total: 200ms	remaining: 77.9ms
# 72:	learn: 2326037.6054405	total: 203ms	remaining: 75ms
# 73:	learn: 2325077.8538141	total: 205ms	remaining: 72.1ms
# 74:	learn: 2323098.6367640	total: 208ms	remaining: 69.3ms
# 75:	learn: 2321798.2452987	total: 211ms	remaining: 66.5ms
# 76:	learn: 2317515.9996124	total: 215ms	remaining: 64.1ms
# 77:	learn: 2312474.1135423	total: 217ms	remaining: 61.3ms
# 78:	learn: 2309560.7106164	total: 220ms	remaining: 58.5ms
# 79:	learn: 2301980.0762033	total: 223ms	remaining: 55.6ms
# 80:	learn: 2299698.2622448	total: 225ms	remaining: 52.8ms
# 81:	learn: 2298301.2575967	total: 229ms	remaining: 50.4ms
# 82:	learn: 2297591.4545263	total: 232ms	remaining: 47.5ms
# 83:	learn: 2294571.1823979	total: 235ms	remaining: 44.7ms
# 84:	learn: 2292618.6062609	total: 237ms	remaining: 41.9ms
# 85:	learn: 2290601.6996467	total: 240ms	remaining: 39.1ms
# 86:	learn: 2287019.3016853	total: 243ms	remaining: 36.4ms
# 87:	learn: 2282736.8721778	total: 247ms	remaining: 33.6ms
# 88:	learn: 2281197.1023574	total: 249ms	remaining: 30.8ms
# 89:	learn: 2280603.1826005	total: 251ms	remaining: 27.9ms
# 90:	learn: 2280122.3777698	total: 254ms	remaining: 25.1ms
# 91:	learn: 2279559.0299882	total: 256ms	remaining: 22.3ms
# 92:	learn: 2274121.7735654	total: 258ms	remaining: 19.5ms
# 93:	learn: 2270378.8661592	total: 261ms	remaining: 16.7ms
# 94:	learn: 2269598.5445018	total: 264ms	remaining: 13.9ms
# 95:	learn: 2267270.6224751	total: 267ms	remaining: 11.1ms
# 96:	learn: 2261296.7685930	total: 270ms	remaining: 8.36ms
# 97:	learn: 2259513.0991289	total: 273ms	remaining: 5.57ms
# 98:	learn: 2257357.3832808	total: 276ms	remaining: 2.78ms
# 99:	learn: 2250264.4556575	total: 279ms	remaining: 0us

# %%
print("######## R-squared (R2) : ")
print("TRAIN :", r2_score(y_train, y_pred_train))
print("TEST :", r2_score(y_test, y_pred))
# Out:
# ######## R-squared (R2) :
# TRAIN : 0.36017534369715354
# TEST : 0.24944232371890263

# %%
# # Créez un dictionnaire avec les caractéristiques du film "Le Bonheur pour les débutants"
# film_data = {
#     'duree': 124,  # Remplacez par la durée du film en minutes
#     'distributeur': 'Wild Bunch Distribution',  # Remplacez par le distributeur du film
#     'nationalités': 'Japon',  # Remplacez par les nationalités du film séparées par des virgules
#     'langue_d_origine': 'Japonais',  # Remplacez par la langue du film
#     'type_film': 'Long-métrage',  # Remplacez par le type du film
# }

# # Transformez le dictionnaire en un dataframe avec une seule ligne
# film_df = pd.DataFrame([film_data])

# # Utilisez le modèle pour prédire le box-office cible du film
# film_prediction = pipeline.predict(film_df)[0]

# print("Box-office prédit du film 'The First Slam Dunk':", film_prediction)

# %%
import joblib

joblib.dump(pipeline, 'pipeml.joblib')
# Out:
# ['pipeml.joblib']
